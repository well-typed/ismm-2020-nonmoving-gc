# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as pl
import numpy as np

# %%
def read_times(fname): 
    queries = []
    adds = []
    for line in open(fname):
        if line.startswith('?'):
            queries.append(float(line[2:]))
        elif line.startswith('+'):
            adds.append(float(line[2:]))
    
    return {'queries': queries, 'additions': adds}

# %%
no = read_times('no')
xn = read_times('xn')

# %%
def hist_times(xn, no, bins=400, log=True, xmax=None):
    real_xmax = max(np.max(xn), np.max(no))
    if xmax is None:
        xmax = real_xmax
    hist_args = {
        'histtype': 'step',
        'alpha': 0.6,
        'bins': bins,
        'log': log,
        'cumulative': -1,
        'normed': True,
        'range': (0, real_xmax)
    }
    pl.hist(no, label='no', color='C1', **hist_args)
    pl.hist(xn, label='xn', color='C0', **hist_args)
    pl.axvline(np.mean(xn), label='xn', lw=0.5, color='C0')
    pl.axvline(np.mean(no), label='no', lw=0.5, color='C1')
    pl.xlim(0, xmax)
    pl.xlabel('latency (seconds)')
    pl.ylabel('inverse cumulative probability')
    print('xn', np.mean(xn))
    print('no', np.mean(no))
    pl.legend()
    pl.xlim(0,xmax)

# %%
pl.figure()
hist_times(xn['queries'], no['queries'], xmax=0.5, bins=1000)
pl.suptitle('far-in query latency distribution')
# Out:
# <img src="data:image/png;base64,..." width="640">
# xn 0.041670726818884826
# no 0.03646046427472528
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   from ipykernel import kernelapp as app
# Text(0.5, 0.98, 'far-in query latency distribution')

# %%
pl.figure()
hist_times(xn['queries'], no['queries'])
pl.suptitle('overall query latency distribution')
# Out:
# <img src="data:image/png;base64,..." width="640">
# xn 0.041670726818884826
# no 0.03646046427472528
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   from ipykernel import kernelapp as app
# Text(0.5, 0.98, 'overall query latency distribution')

# %%
pl.figure()
hist_times(xn['additions'], no['additions'])
pl.suptitle('overall index latency distribution')
# Out:
# <img src="data:image/png;base64,..." width="640">
# xn 0.32757790765634365
# no 0.2273587397782218
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /nix/store/nzfcpq2c01fx2g9b93lic97ygy765rx9-python3-3.7.5-env/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   from ipykernel import kernelapp as app
# Text(0.5, 0.98, 'overall index latency distribution')
